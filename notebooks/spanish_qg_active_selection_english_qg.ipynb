# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from collections import defaultdict
import seaborn as sns
import json
import torch
import pickle

import matplotlib
matplotlib.rcParams.update({'font.size': 14})
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "DeJavu Serif"

# %%
df_all = pd.DataFrame()

# %%
perp_folders = ["../output/5050_english_qg/"]

# %%
for perp_folder in perp_folders:
    files = os.listdir(perp_folder)
    files = [os.path.join(perp_folder, f) for f in files] # add path to each file
    files.sort(key=lambda x: os.path.getmtime(x), reverse=True)

    # print(files)
    
    for file in files:        
        if "opposite" in file or "emb" in file or "predictions" in file or "proportions" in file:
            continue 
        
        # if "english" not in file:
        #     continue 
                
        if ".log" in file:
            continue
        print(file)
        method = file.split("/")[-1]
        
        runs = os.listdir(file)
        
        for run in runs:
            if "proportions" in run:
                continue 
            seed = int(run.split("seed_")[-1].split("_")[0])
            checkpoint = int(run.split("-")[-1].split(".")[0])
            if len(df_all) != 0:
                if len(df_all.loc[(df_all.method==method) & (df_all.seed == seed) & (df_all.index==checkpoint)]) != 0:
                    continue 
                
            path = os.path.join(file, run)
            print(path)
                
            loss_dict = pd.read_pickle(path)
        
        
            df = pd.DataFrame([{"skill": k, "loss": [values.numpy() if torch.is_tensor(values) else values for values in v]} for k, v in loss_dict.items()])
            df["perplexity"] = pd.Series([np.exp(l) for l in df["loss"].values])
            df["average_loss"] = pd.Series([sum(l)/len(l) for l in df["loss"].values])
            df["average_perplexity"] = pd.Series([sum(p)/len(p) for p in df["perplexity"].values])
            df["method"] = method
            df["seed"] = seed
            df["checkpoint"] = checkpoint


            df.set_index("checkpoint", inplace=True)


            df_all = pd.concat([df_all, df])
# Out:
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_3_checkpoint-0.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_1_checkpoint-0.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_2_checkpoint-100.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_0_checkpoint-500.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_3_checkpoint-600.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_0_checkpoint-0.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_4_checkpoint-400.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_3_checkpoint-400.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_1_checkpoint-200.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_0_checkpoint-600.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_1_checkpoint-400.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_0_checkpoint-100.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_2_checkpoint-200.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_4_checkpoint-200.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_1_checkpoint-100.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_1_checkpoint-500.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_4_checkpoint-100.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_1_checkpoint-600.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_0_checkpoint-300.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_2_checkpoint-500.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_4_checkpoint-500.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_3_checkpoint-100.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_2_checkpoint-0.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_2_checkpoint-600.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_3_checkpoint-200.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_1_checkpoint-300.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_0_checkpoint-400.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_4_checkpoint-300.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_3_checkpoint-500.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_2_checkpoint-300.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_3_checkpoint-300.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_4_checkpoint-600.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_4_checkpoint-0.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_0_checkpoint-200.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints/seed_2_checkpoint-400.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_3_checkpoint-0.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_1_checkpoint-0.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_2_checkpoint-100.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_0_checkpoint-500.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_3_checkpoint-600.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_0_checkpoint-0.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_4_checkpoint-400.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_3_checkpoint-400.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_1_checkpoint-200.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_0_checkpoint-600.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_1_checkpoint-400.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_0_checkpoint-100.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_2_checkpoint-200.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_4_checkpoint-200.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_1_checkpoint-100.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_1_checkpoint-500.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_4_checkpoint-100.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_1_checkpoint-600.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_0_checkpoint-300.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_2_checkpoint-500.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_4_checkpoint-500.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_3_checkpoint-100.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_2_checkpoint-0.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_2_checkpoint-600.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_3_checkpoint-200.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_1_checkpoint-300.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_0_checkpoint-400.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_4_checkpoint-300.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_3_checkpoint-500.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_2_checkpoint-300.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_3_checkpoint-300.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_4_checkpoint-600.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_4_checkpoint-0.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_0_checkpoint-200.pkl
# ../output/5050_english_qg/ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static/seed_2_checkpoint-400.pkl

# %%
def aggregate_skill(x, ppl=True):
    if ppl:
        total_ppl = x["perplexity"].apply(lambda x: sum(x)).sum()
        count_ppl = x["perplexity"].apply(lambda x: len(x)).sum()
        metric_name = "skill_perplexity"
        metric = total_ppl/count_ppl
    else:
        total_loss = x["loss"].apply(lambda x: sum(x)).sum()
        count_loss = x["loss"].apply(lambda x: len(x)).sum()
        metric_name = "skill_loss"
        metric = total_loss/count_loss

    names = {metric_name: metric}
    
    return pd.Series(names, index=[metric_name])

# %%
sorted(df_all.method.unique())
# Out:
# ['ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0010_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints',
#  'ni_xlingual_600_mixture_question_answering_english_english_question_genera_weights_00_static']

# %%
methods = sorted(df_all.method.unique())

labels = ["skill-it", "5050"]
# labels = ["Skill-it", "Real + Synthetic Augmentation", "Target Only"]

# methods = [
#     "real",
    # "synthetic_v2",
    # "synthetic_v3",
    # "synthetic_v4",
    # "synthetic_v4_05_split",
    # "synthetic_v4_075_split",
    # "synthetic_v4_09_split",
    # "target_only",

    # "ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0001_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints copy",
    # "english_v3",
    # "ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0001_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints",
    # "ni_xlingual_600_mixture_question_answering_english_english_question_answer_targetmask_0001_mean_spanish_qg_normalized_greedy_100_eta_0.8_lookback_3_checkpoints",
# ]
# labels = [
#     "Skill-It", 
#     # "Synthetic v1", 
#     # "Synthetic v2", 
#     "Synthetic v4", 
#     "Synthetic v4 (0.5 split)",
#     "Synthetic v4 (0.75 split)",
#     "Synthetic v4 (0.9 split)",
#     "Target Baseline"
# ]

assert len(methods) == len(labels)
plt.figure()
seeds=[0, 1, 2, 3, 4]


for i, method in enumerate(methods):
    
    df_shuffled = df_all.loc[df_all.method == method].sort_index()
    print(df_shuffled.seed.unique())
    df_shuffled = df_shuffled.loc[df_shuffled.seed.isin(seeds)]
    df_overall = df_shuffled.groupby([df_shuffled.index]).apply(lambda x: aggregate_skill(x, ppl=False)).reset_index()
    df_shuffled = df_shuffled.groupby([df_shuffled.index, "skill"]).apply(lambda x: aggregate_skill(x, ppl=False)).reset_index()
    df_shuffled.set_index("checkpoint", inplace=True)
    df_overall.set_index("checkpoint", inplace=True)
    df_overall.drop([0], inplace=True)

    df_shuffled.loc[df_shuffled.skill == "question_generation_english_english"].skill_loss.plot(marker="o", label=labels[i], lw=3)
    print(df_shuffled.loc[df_shuffled.index == df_shuffled.index.max()].skill_loss)



plt.xlim(110, )
plt.ylim(2.5, 3.5)
plt.xlabel("Steps")
plt.ylabel("Validation Loss")
plt.legend(loc='upper right')
plt.grid()
plt.title("Targeted learning of English QG")
# Out:
# [3 4 0 2 1]
# checkpoint
# 600    2.673270
# 600    2.389471
# 600    2.752675
# 600    2.400844
# Name: skill_loss, dtype: float64
# [3 1 2 0 4]
# /tmp/ipykernel_2347038/3587277359.py:43: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_shuffled = df_shuffled.groupby([df_shuffled.index, "skill"]).apply(lambda x: aggregate_skill(x, ppl=False)).reset_index()
# /tmp/ipykernel_2347038/3587277359.py:43: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_shuffled = df_shuffled.groupby([df_shuffled.index, "skill"]).apply(lambda x: aggregate_skill(x, ppl=False)).reset_index()
# checkpoint
# 600    2.572550
# 600    2.735293
# Name: skill_loss, dtype: float64
# Text(0.5, 1.0, 'Targeted learning of English QG')

# %%
df_all.columns
# Out:
# Index(['skill', 'loss', 'perplexity', 'average_loss', 'average_perplexity',
#        'method', 'seed'],
#       dtype='object')

# %%
df_all[df_all['skill'] == "question_generation_spanish_spanish"].sort_values(by=["checkpoint", "seed"])
# Out:
#                                           skill  \
# checkpoint
# 0           question_generation_spanish_spanish
# 0           question_generation_spanish_spanish
# 0           question_generation_spanish_spanish
# 0           question_generation_spanish_spanish
# 0           question_generation_spanish_spanish
# 100         question_generation_spanish_spanish
# 100         question_generation_spanish_spanish
# 100         question_generation_spanish_spanish
# 100         question_generation_spanish_spanish
# 100         question_generation_spanish_spanish
# 200         question_generation_spanish_spanish
# 200         question_generation_spanish_spanish
# 200         question_generation_spanish_spanish
# 200         question_generation_spanish_spanish
# 200         question_generation_spanish_spanish
# 300         question_generation_spanish_spanish
# 300         question_generation_spanish_spanish
# 300         question_generation_spanish_spanish
# 300         question_generation_spanish_spanish
# 300         question_generation_spanish_spanish
# 400         question_generation_spanish_spanish
# 400         question_generation_spanish_spanish
# 400         question_generation_spanish_spanish
# 400         question_generation_spanish_spanish
# 400         question_generation_spanish_spanish
# 500         question_generation_spanish_spanish
# 500         question_generation_spanish_spanish
# 500         question_generation_spanish_spanish
# 500         question_generation_spanish_spanish
# 500         question_generation_spanish_spanish
# 600         question_generation_spanish_spanish
# 600         question_generation_spanish_spanish
# 600         question_generation_spanish_spanish
# 600         question_generation_spanish_spanish
# 600         question_generation_spanish_spanish
#
#                                                          loss  \
# checkpoint
# 0           [2.8477883, 3.0934598, 2.7725923, 2.9614944, 2...
# 0           [2.8799655, 3.145936, 2.5499837, 2.8836033, 2....
# 0           [2.8111508, 2.3343627, 3.187772, 2.8529174, 2....
# 0           [2.749771, 3.4148657, 2.72377, 3.0468252, 2.92...
# 0           [2.35559, 2.4685526, 2.6569357, 2.8469462, 2.7...
# 100         [2.3960927, 2.7060003, 2.3566809, 2.5443578, 2...
# 100         [2.4664552, 2.7137816, 2.5337408, 2.4359646, 2...
# 100         [2.418834, 2.1956108, 2.6235673, 2.4529681, 2....
# 100         [2.3483958, 3.049608, 2.2331553, 2.916909, 2.7...
# 100         [2.2774172, 2.2225802, 2.2427166, 2.3695843, 2...
# 200         [2.3015943, 2.6423438, 2.283826, 2.4581463, 2....
# 200         [2.4077127, 2.6655378, 2.483434, 2.3643305, 2....
# 200         [2.3775737, 2.1797712, 2.5815997, 2.402208, 2....
# 200         [2.3032985, 3.0196722, 2.1699564, 2.8185449, 2...
# 200         [2.2422125, 2.1870499, 2.1751144, 2.3318307, 2...
# 300         [2.2750404, 2.6384518, 2.2856915, 2.4475276, 2...
# 300         [2.4084337, 2.6342857, 2.4766743, 2.3556197, 2...
# 300         [2.348349, 2.1736817, 2.552119, 2.3295438, 2.3...
# 300         [2.2658908, 2.9987414, 2.1599524, 2.7453554, 2...
# 300         [2.23841, 2.1760654, 2.151417, 2.3184996, 2.48...
# 400         [2.251948, 2.6277971, 2.263807, 2.4308953, 2.0...
# 400         [2.3837383, 2.6233988, 2.4600523, 2.3410842, 2...
# 400         [2.3408144, 2.180491, 2.5499024, 2.3273072, 2....
# 400         [2.2486646, 3.000691, 2.1360037, 2.6932342, 2....
# 400         [2.2373698, 2.1879444, 2.141476, 2.293774, 2.4...
# 500         [2.2466772, 2.6196737, 2.2521327, 2.431325, 2....
# 500         [2.3690376, 2.6259217, 2.4538593, 2.3299034, 2...
# 500         [2.332147, 2.1699128, 2.54007, 2.3310056, 2.30...
# 500         [2.2393377, 2.9965065, 2.1402745, 2.7057426, 2...
# 500         [2.2219043, 2.179738, 2.1290696, 2.2917104, 2....
# 600         [2.244604, 2.6207511, 2.2463198, 2.427558, 2.0...
# 600         [2.3746066, 2.6207337, 2.4568546, 2.3325136, 2...
# 600         [2.3428462, 2.1681316, 2.527511, 2.3255804, 2....
# 600         [2.2403667, 2.990475, 2.1340113, 2.7012572, 2....
# 600         [2.2195458, 2.183254, 2.124772, 2.2838273, 2.4...
#
#                                                    perplexity  average_loss  \
# checkpoint
# 0           [17.24959, 22.053247, 16.000057, 19.326834, 9....      2.920899
# 0           [17.81366, 23.241417, 12.806894, 17.87858, 16....      2.912400
# 0           [16.629044, 10.32288, 24.234375, 17.338291, 16...      2.918779
# 0           [15.639052, 30.412868, 15.237659, 21.048412, 1...      2.916496
# 0           [10.54435, 11.805346, 14.252547, 17.23507, 15....      2.910948
# 100         [10.980189, 14.969283, 10.555857, 12.735046, 8...      2.546488
# 100         [11.780613, 15.086217, 12.600554, 11.426835, 1...      2.567993
# 100         [11.232754, 8.985488, 13.784812, 11.622793, 10...      2.564485
# 100         [10.468762, 21.107069, 9.329256, 18.484064, 16...      2.592310
# 100         [9.751462, 9.231118, 9.418883, 10.692946, 12.4...      2.522560
# 200         [9.990097, 14.046086, 9.814158, 11.683135, 8.1...      2.481983
# 200         [11.108524, 14.375679, 11.98234, 10.636914, 14...      2.497889
# 200         [10.778719, 8.844282, 13.218267, 11.047543, 10...      2.493631
# 200         [10.007136, 20.484573, 8.757903, 16.752455, 15...      2.506519
# 200         [9.414137, 8.908892, 8.803192, 10.296775, 11.7...      2.448530
# 300         [9.7283125, 13.991526, 9.832483, 11.5597315, 8...      2.469783
# 300         [11.116535, 13.933355, 11.901617, 10.544661, 1...      2.478934
# 300         [10.468273, 8.790589, 12.8342705, 10.273254, 1...      2.468008
# 300         [9.6397085, 20.060272, 8.670725, 15.570146, 15...      2.477039
# 300         [9.3784075, 8.811569, 8.597032, 10.1604185, 11...      2.434245
# 400         [9.506237, 13.843242, 9.619642, 11.369056, 8.0...      2.457735
# 400         [10.84537, 13.782488, 11.705422, 10.392498, 14...      2.460663
# 400         [10.389694, 8.850651, 12.805854, 10.250303, 10...      2.454642
# 400         [9.475074, 20.09942, 8.465539, 14.779398, 14.4...      2.466311
# 400         [9.368657, 8.916865, 8.511991, 9.912275, 11.82...      2.423524
# 500         [9.456262, 13.731243, 9.507992, 11.373941, 8.1...      2.448784
# 500         [10.687102, 13.817305, 11.633156, 10.276949, 1...      2.453905
# 500         [10.300031, 8.757521, 12.680559, 10.288281, 10...      2.449213
# 500         [9.387112, 20.01549, 8.501771, 14.9654255, 14....      2.456659
# 500         [9.22488, 8.843989, 8.407041, 9.891843, 11.857...      2.415195
# 600         [9.436679, 13.746045, 9.452883, 11.331177, 8.1...      2.445750
# 600         [10.746785, 13.745806, 11.668054, 10.303808, 1...      2.453122
# 600         [10.410825, 8.741936, 12.522298, 10.232616, 10...      2.446999
# 600         [9.396776, 19.89513, 8.4486885, 14.898452, 14....      2.453174
# 600         [9.203151, 8.875139, 8.37099, 9.814171, 11.745...      2.411438
#
#             average_perplexity  \
# checkpoint
# 0                    19.263206
# 0                    19.151660
# 0                    19.343482
# 0                    19.250611
# 0                    19.231240
# 100                  13.318638
# 100                  13.647678
# 100                  13.591952
# 100                  13.955413
# 100                  12.981183
# 200                  12.533657
# 200                  12.759075
# 200                  12.698718
# 200                  12.827652
# 200                  12.078851
# 300                  12.401656
# 300                  12.532445
# 300                  12.403843
# 300                  12.463053
# 300                  11.915520
# 400                  12.256295
# 400                  12.295239
# 400                  12.244957
# 400                  12.345505
# 400                  11.810111
# 500                  12.151244
# 500                  12.219626
# 500                  12.181437
# 500                  12.218799
# 500                  11.705276
# 600                  12.112530
# 600                  12.208448
# 600                  12.160119
# 600                  12.177945
# 600                  11.661804
#
#                                                        method  seed
# checkpoint
# 0           ni_xlingual_600_mixture_question_answering_eng...     0
# 0           ni_xlingual_600_mixture_question_answering_eng...     1
# 0           ni_xlingual_600_mixture_question_answering_eng...     2
# 0           ni_xlingual_600_mixture_question_answering_eng...     3
# 0           ni_xlingual_600_mixture_question_answering_eng...     4
# 100         ni_xlingual_600_mixture_question_answering_eng...     0
# 100         ni_xlingual_600_mixture_question_answering_eng...     1
# 100         ni_xlingual_600_mixture_question_answering_eng...     2
# 100         ni_xlingual_600_mixture_question_answering_eng...     3
# 100         ni_xlingual_600_mixture_question_answering_eng...     4
# 200         ni_xlingual_600_mixture_question_answering_eng...     0
# 200         ni_xlingual_600_mixture_question_answering_eng...     1
# 200         ni_xlingual_600_mixture_question_answering_eng...     2
# 200         ni_xlingual_600_mixture_question_answering_eng...     3
# 200         ni_xlingual_600_mixture_question_answering_eng...     4
# 300         ni_xlingual_600_mixture_question_answering_eng...     0
# 300         ni_xlingual_600_mixture_question_answering_eng...     1
# 300         ni_xlingual_600_mixture_question_answering_eng...     2
# 300         ni_xlingual_600_mixture_question_answering_eng...     3
# 300         ni_xlingual_600_mixture_question_answering_eng...     4
# 400         ni_xlingual_600_mixture_question_answering_eng...     0
# 400         ni_xlingual_600_mixture_question_answering_eng...     1
# 400         ni_xlingual_600_mixture_question_answering_eng...     2
# 400         ni_xlingual_600_mixture_question_answering_eng...     3
# 400         ni_xlingual_600_mixture_question_answering_eng...     4
# 500         ni_xlingual_600_mixture_question_answering_eng...     0
# 500         ni_xlingual_600_mixture_question_answering_eng...     1
# 500         ni_xlingual_600_mixture_question_answering_eng...     2
# 500         ni_xlingual_600_mixture_question_answering_eng...     3
# 500         ni_xlingual_600_mixture_question_answering_eng...     4
# 600         ni_xlingual_600_mixture_question_answering_eng...     0
# 600         ni_xlingual_600_mixture_question_answering_eng...     1
# 600         ni_xlingual_600_mixture_question_answering_eng...     2
# 600         ni_xlingual_600_mixture_question_answering_eng...     3
# 600         ni_xlingual_600_mixture_question_answering_eng...     4

# %%
# df_all[df_all['skill'] == "question_generation_spanish_spanish"].sort_values(by=["checkpoint", "seed"])
df_all[df_all.index == 600].sort_values(by=["checkpoint", "seed"]).groupby("skill").agg({"average_loss": "mean"})
# Out:
#                                      average_loss
# skill
# question_answering_english_english       2.718926
# question_answering_spanish_spanish       1.583033
# question_generation_english_english      2.878385
# question_generation_spanish_spanish      2.442097
